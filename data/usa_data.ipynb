# %% [markdown]
# Import USA data

# %%
import pandas as pd
import glob
import os

#get path for os
path = os.getcwd() + "/data_source/USA/covid-tracking-data-master/data/states_daily_4pm_et.csv"
path = path.replace("/",os.path.sep)

#Data of healed are not present
#Home isolation are positive - hospitalized
#Intensive care and recovered is not present

columns = ["total_cases","daily_cases","actual_cases","total_dead","daily_dead",
                  "total_home_isolation","daily_home_isolation",
                  "total_hospitalized","daily_hospitalized","total_test","daily_test"]


dataset = pd.read_csv(path, index_col = 0)
dataset = dataset.fillna(0)

# %% [markdown]
# Grouping by date

# %%
dataset = dataset.groupby(["date"]).sum()
dataset
# Out:
#           positive   negative  pending  hospitalizedCurrently  \
# date
# 20200122       1.0        0.0      0.0                    0.0
# 20200123       1.0        0.0      0.0                    0.0
# 20200124       1.0        0.0      0.0                    0.0
# 20200125       1.0        0.0      0.0                    0.0
# 20200126       1.0        0.0      0.0                    0.0
# ...            ...        ...      ...                    ...
# 20200420  773020.0  3231027.0   4037.0                55509.0
# 20200421  800305.0  3355282.0   3956.0                58468.0
# 20200422  827963.0  3641232.0   4191.0                58173.0
# 20200423  859318.0  3800932.0   4258.0                57879.0
# 20200424  890816.0  3992986.0   4396.0                56118.0
#
#           hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# date
# 20200122                     0.0             0.0              0.0
# 20200123                     0.0             0.0              0.0
# 20200124                     0.0             0.0              0.0
# 20200125                     0.0             0.0              0.0
# 20200126                     0.0             0.0              0.0
# ...                          ...             ...              ...
# 20200420                 82879.0         14691.0           2193.0
# 20200421                 84292.0         15228.0           2315.0
# 20200422                 85543.0         15341.0           2370.0
# 20200423                 91108.0         15163.0           2428.0
# 20200424                 93107.0         15078.0           2468.0
#
#           onVentilatorCurrently  onVentilatorCumulative  recovered  ...  \
# date                                                                ...
# 20200122                    0.0                     0.0        0.0  ...
# 20200123                    0.0                     0.0        0.0  ...
# 20200124                    0.0                     0.0        0.0  ...
# 20200125                    0.0                     0.0        0.0  ...
# 20200126                    0.0                     0.0        0.0  ...
# ...                         ...                     ...        ...  ...
# 20200420                 5567.0                   214.0    54438.0  ...
# 20200421                 5514.0                   214.0    58117.0  ...
# 20200422                 5474.0                   227.0    61519.0  ...
# 20200423                 5464.0                   227.0    63547.0  ...
# 20200424                 5187.0                   227.0    80958.0  ...
#
#           hospitalized      total  totalTestResults     posNeg  fips  \
# date
# 20200122           0.0        1.0               1.0        1.0    53
# 20200123           0.0        1.0               1.0        1.0    53
# 20200124           0.0        1.0               1.0        1.0    53
# 20200125           0.0        1.0               1.0        1.0    53
# 20200126           0.0        1.0               1.0        1.0    53
# ...                ...        ...               ...        ...   ...
# 20200420       82879.0  4008084.0         4004047.0  4004047.0  1822
# 20200421       84292.0  4159543.0         4155587.0  4155587.0  1822
# 20200422       85543.0  4473386.0         4469195.0  4469195.0  1822
# 20200423       91108.0  4664508.0         4660250.0  4660250.0  1822
# 20200424       93107.0  4888198.0         4883802.0  4883802.0  1822
#
#           deathIncrease  hospitalizedIncrease  negativeIncrease  \
# date
# 20200122            0.0                   0.0               0.0
# 20200123            0.0                   0.0               0.0
# 20200124            0.0                   0.0               0.0
# 20200125            0.0                   0.0               0.0
# 20200126            0.0                   0.0               0.0
# ...                 ...                   ...               ...
# 20200420         1528.0                1998.0          114366.0
# 20200421         2674.0                1413.0          124255.0
# 20200422         2133.0                1251.0          285950.0
# 20200423         1886.0                5601.0          159700.0
# 20200424         1772.0                1999.0          192054.0
#
#           positiveIncrease  totalTestResultsIncrease
# date
# 20200122               0.0                       0.0
# 20200123               0.0                       0.0
# 20200124               0.0                       0.0
# 20200125               0.0                       0.0
# 20200126               0.0                       0.0
# ...                    ...                       ...
# 20200420           23534.0                  137900.0
# 20200421           27285.0                  151540.0
# 20200422           27658.0                  313608.0
# 20200423           31355.0                  191055.0
# 20200424           31498.0                  223552.0
#
# [94 rows x 21 columns]

# %% [markdown]
# Converting dates from String to Datetime

# %%
import datetime as dt

index_list = dataset.index.tolist()

for i in range(len(index_list)):
    index_list[i] = dt.datetime.strptime(str(index_list[i]), '%Y%m%d').date()

dataset.index = index_list
dataset.index.name = 'date'

dataset.index[0]
# Out:
# datetime.date(2020, 1, 22)

# %% [markdown]
# Creating a new dataframe with our specific format

# %%
usa_dataset = pd.DataFrame().reindex_like(dataset)
usa_dataset = pd.DataFrame(index = dataset.index , columns = columns) 
usa_dataset = usa_dataset.fillna(0)
usa_dataset
# Out:
#             total_cases  daily_cases  actual_cases  total_dead  daily_dead  \
# date
# 2020-01-22            0            0             0           0           0
# 2020-01-23            0            0             0           0           0
# 2020-01-24            0            0             0           0           0
# 2020-01-25            0            0             0           0           0
# 2020-01-26            0            0             0           0           0
# ...                 ...          ...           ...         ...         ...
# 2020-04-20            0            0             0           0           0
# 2020-04-21            0            0             0           0           0
# 2020-04-22            0            0             0           0           0
# 2020-04-23            0            0             0           0           0
# 2020-04-24            0            0             0           0           0
#
#             total_home_isolation  daily_home_isolation  total_hospitalized  \
# date
# 2020-01-22                     0                     0                   0
# 2020-01-23                     0                     0                   0
# 2020-01-24                     0                     0                   0
# 2020-01-25                     0                     0                   0
# 2020-01-26                     0                     0                   0
# ...                          ...                   ...                 ...
# 2020-04-20                     0                     0                   0
# 2020-04-21                     0                     0                   0
# 2020-04-22                     0                     0                   0
# 2020-04-23                     0                     0                   0
# 2020-04-24                     0                     0                   0
#
#             daily_hospitalized  total_test  daily_test
# date
# 2020-01-22                   0           0           0
# 2020-01-23                   0           0           0
# 2020-01-24                   0           0           0
# 2020-01-25                   0           0           0
# 2020-01-26                   0           0           0
# ...                        ...         ...         ...
# 2020-04-20                   0           0           0
# 2020-04-21                   0           0           0
# 2020-04-22                   0           0           0
# 2020-04-23                   0           0           0
# 2020-04-24                   0           0           0
#
# [94 rows x 11 columns]

# %% [markdown]
# Filling the new dataframe with the avaiable data

# %%
day = []
for days in dataset.index:
    try:
        #from 2nd row
        usa_dataset.loc[days]["daily_cases"] = dataset.loc[days]["positiveIncrease"]
        usa_dataset.loc[days]["daily_dead"] = dataset.loc[days]["deathIncrease"]
        usa_dataset.loc[days]["daily_home_isolation"] = (dataset.loc[days]["positive"] - dataset.loc[days]["hospitalized"] - dataset.loc[days]["death"]) - (dataset.loc[days-dt.timedelta(days=1)]["positive"] - dataset.loc[days-dt.timedelta(days=1)]["hospitalized"] - dataset.loc[days-dt.timedelta(days=1)]["death"]) #Instead of positive should be actual cases
        usa_dataset.loc[days]["daily_hospitalized"] = dataset.loc[days]["hospitalized"] - dataset.loc[days-dt.timedelta(days=1)]["hospitalized"]
        usa_dataset.loc[days]["daily_test"] = dataset.loc[days]["total"] - dataset.loc[days-dt.timedelta(days=1)]["total"]
    except:
        #First row
        usa_dataset.loc[days]["daily_cases"] = dataset.loc[days]["positive"]
        usa_dataset.loc[days]["daily_dead"] = dataset.loc[days]["death"]
        usa_dataset.loc[days]["daily_home_isolation"] = (dataset.loc[days]["positive"] - dataset.loc[days]["hospitalized"] - dataset.loc[days]["death"]) #Instead of positive should be actual cases
        usa_dataset.loc[days]["daily_hospitalized"] = dataset.loc[days]["hospitalized"]
        usa_dataset.loc[days]["daily_test"] = dataset.loc[days]["total"]
    finally:
        #Single row
        usa_dataset.loc[days]["total_cases"] = dataset.loc[days]["positive"]
        usa_dataset.loc[days]["actual_cases"] = dataset.loc[days]["positive"] - dataset.loc[days]["recovered"] - dataset.loc[days]["death"]
        usa_dataset.loc[days]["total_dead"] = dataset.loc[days]["death"]
        usa_dataset.loc[days]["total_home_isolation"] = dataset.loc[days]["positive"]-dataset.loc[days]["hospitalized"] - dataset.loc[days]["death"] #Instead of positive should be actual cases
        usa_dataset.loc[days]["total_hospitalized"] = dataset.loc[days]["hospitalized"]
        usa_dataset.loc[days]["total_test"] = dataset.loc[days]["total"]


usa_dataset
# Out:
#             total_cases  daily_cases  actual_cases  total_dead  daily_dead  \
# date
# 2020-01-22            1            1             1           0           0
# 2020-01-23            1            0             1           0           0
# 2020-01-24            1            0             1           0           0
# 2020-01-25            1            0             1           0           0
# 2020-01-26            1            0             1           0           0
# ...                 ...          ...           ...         ...         ...
# 2020-04-20       773020        23534        681261       37321        1528
# 2020-04-21       800305        27285        702193       39995        2674
# 2020-04-22       827963        27658        724316       42128        2133
# 2020-04-23       859318        31355        751757       44014        1886
# 2020-04-24       890816        31498        764072       45786        1772
#
#             total_home_isolation  daily_home_isolation  total_hospitalized  \
# date
# 2020-01-22                     1                     1                   0
# 2020-01-23                     1                     0                   0
# 2020-01-24                     1                     0                   0
# 2020-01-25                     1                     0                   0
# 2020-01-26                     1                     0                   0
# ...                          ...                   ...                 ...
# 2020-04-20                652820                 20008               82879
# 2020-04-21                676018                 23198               84292
# 2020-04-22                700292                 24274               85543
# 2020-04-23                724196                 23904               91108
# 2020-04-24                751923                 27727               93107
#
#             daily_hospitalized  total_test  daily_test
# date
# 2020-01-22                   0           1           1
# 2020-01-23                   0           1           0
# 2020-01-24                   0           1           0
# 2020-01-25                   0           1           0
# 2020-01-26                   0           1           0
# ...                        ...         ...         ...
# 2020-04-20                1998     4008084      130613
# 2020-04-21                1413     4159543      151459
# 2020-04-22                1251     4473386      313843
# 2020-04-23                5565     4664508      191122
# 2020-04-24                1999     4888198      223690
#
# [94 rows x 11 columns]

# %%
#get path for os
path = os.getcwd() + "/parsed_data/usa/"
path = path.replace("/",os.path.sep)
#save data as CSV 
usa_dataset.to_csv (path + "usa.csv", index = True, header=True)
